# %% [markdown]
# # 활성화 함수와 초기값에 따른 weight 분포

# %%
import torch
import torch.nn as nn

# %%
x = torch.normal(0,1, size=(1000,100))

activations = {}

for i in range(5):
    fc = nn.Linear(100,100)
    fc.weight = nn.Parameter(torch.normal(0, 1, size=fc.weight.shape))
    
    x = fc(x)
    x = sig(x)
    activations[i] = x

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(len(activations)):
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + '-layer')
    plt.hist(activations[i].flatten().detach().numpy(), 30, range=(0,1))
